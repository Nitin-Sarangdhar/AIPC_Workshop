# %%
# !ls -l
# !pwd
# !pip install yolov5
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5

# %%
# !python detect.py --weights yolov5s.pt --source data/images/zidane.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/drive/MyDrive/Helmet and no helmet rider detection.v6-balanced-dataset.yolov5pytorch.zip" -d /content/yolov5

# %%
# !ls

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --data /content/yolov5/data.yaml --weights yolov5s.pt --epochs 200

# %%
# !ls

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --include onnx --imgsz 640 --half --device 0

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# The `force_remount=True` ensures the drive is remounted with the new permissions.

# %%
# Example: Copy a file from your Colab session to a shared drive
# !cp -r runs "/content/drive/MyDrive"

# %%
from google.colab import runtime

# Your code to save the results goes here...
# For example:
# !cp -r runs "/content/drive/Shared drives/My Shared Drive/Project_Results"

# Disconnect and free up the GPU
runtime.unassign()
